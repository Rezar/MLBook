# %%
import numpy as np
import matplotlib.pyplot as plt

# creating a sample time domain signal
t = np.linspace(0, 0.5, 500)
s = np.sin(40 * 2 * np.pi * t) + 0.5 * np.sin(90 * 2 * np.pi * t)

#Show the sample signal
plt.ylabel("Amplitude")
plt.xlabel("Time [s]")
plt.plot(t, s)
plt.rcParams["figure.format"] = "svg"
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in __setitem__(self, key, val)
#     676             try:
# --> 677                 cval = self.validate[key](val)
#     678             except ValueError as ve:
#
# KeyError: 'figure.format'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/jr/tpgq1lds0rx3dd59myq8rn7h0000gr/T/ipykernel_12808/3132689183.py in <module>
#      10 plt.xlabel("Time [s]")
#      11 plt.plot(t, s)
# ---> 12 plt.rcParams['figure.format'] = 'svg'
#      13 plt.show()
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in __setitem__(self, key, val)
#     680             dict.__setitem__(self, key, cval)
#     681         except KeyError as err:
# --> 682             raise KeyError(
#     683                 f"{key} is not a valid rc parameter (see rcParams.keys() for "
#     684                 f"a list of valid parameters)") from err
#
# KeyError: 'figure.format is not a valid rc parameter (see rcParams.keys() for a list of valid parameters)'

# %%
# convert the Time signal into Frequency Signal with FFT
fft = np.fft.fft(s)
#print(fft)
T = t[1] - t[0]  # sampling interval 
N = s.size

# 1/T = frequency
f = np.linspace(0, 1 / T, N)

plt.ylabel("Amplitude")
plt.xlabel("Frequency [Hz]")
plt.bar(f[:N // 2], np.abs(fft)[:N // 2] * 1 / N, width=1.5)  # 1 / N is a normalization factor
plt.show()
