# %%
import networkx as nx
import networkx.algorithms.tree as tree
from networkx.generators.random_graphs import erdos_renyi_graph

# %%
G0 = nx.Graph()

G0.add_edge(1, 2) # default edge data=1
G0.add_edge(2, 3)
G0.add_edge(1, 3)
G0.add_edge(1, 4)
G0.add_edge(4, 5)
G0.add_edge(4, 6)

nx.draw_networkx(G0, with_labels = True, node_color='lightgreen')

# %%
G = nx.Graph()
elist = [(1, 2), (2, 3), (1,3),(1, 4), (4, 2), (4, 6), (5, 6), (5,7), (5,8), (6,7) ]
#nlist = nx.Graph([(0, 1), (1, 2), (2, 0)]) 
G.add_edges_from(elist)
#G.add_nodes_from(nlist)
#elist = [('a', 'b', 5.0), ('b', 'c', 3.0), ('a', 'c', 1.0), ('c', 'd', 7.3)]
#G.add_weighted_edges_from(elist)

nx.draw_networkx(G,  with_labels = True, node_color='yellow')

# %%
# Prim Algorithm
mst = tree.minimum_spanning_edges(G, algorithm='prim', data=False)
edgelist = list(mst)
sorted(edgelist)

G2 = nx.Graph()
G2.add_edges_from(edgelist)

nx.draw_networkx(G2,  with_labels = True, node_color='yellow')

# %%
# Kruskal Algorithm
mst = tree.minimum_spanning_edges(G, algorithm='kruskal', data=False)
edgelist = list(mst)
sorted(edgelist)

G2 = nx.Graph()
G2.add_edges_from(edgelist)

nx.draw_networkx(G2,  with_labels = True, node_color='yellow')

# %%
# create random graph
n = 12
p = 0.2
g = erdos_renyi_graph(n, p)

pos = nx.spring_layout(g)
nx.draw_networkx(g, with_labels = True, edge_color='grey', node_color='#74d4e8')

# %%
#source: 1, path: 4
print(nx.dijkstra_path(g,1,6))
# Out:
# [1, 9, 2, 6]

# %%
# ------ A * search ------
import networkx as nx
import matplotlib.pyplot as plt 

# --- this function is used to assign heuristic distance h(n) ----
def dist(a, b):
    (x1, y1) = a
    (x2, y2) = b
    return ((x1 - x2) ** 2 + (y1 - y2) ** 2) ** 0.5


G = nx.grid_graph(dim=[3, 3])  # nodes are two-tuples (x,y)
nx.set_edge_attributes(G, {e: e[1][0] * 2 for e in G.edges()}, "cost")
path = nx.astar_path(G, (0, 0), (2, 2), heuristic=dist, weight="cost")
length = nx.astar_path_length(G, (0, 0), (2, 2), heuristic=dist, weight="cost")
print('Path:')
print(path)
print("Path length: ") 
print(length)

pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels = True, node_color="yellow")
edge_labels = nx.get_edge_attributes(G, "cost")
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
plt.show()
# Out:
# Path:
# [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Path length:
# 6

# %%
G = nx.Graph()
elist = [(1, 2), (2, 3), (1,3),(1, 4), (4, 2), (4, 6), (5, 6), (5,7), (5,8), (6,7), ]
#nlist = nx.Graph([(0, 1), (1, 2), (2, 0)]) 
G.add_edges_from(elist)
#G.add_nodes_from(nlist)
#elist = [('a', 'b', 5.0), ('b', 'c', 3.0), ('a', 'c', 1.0), ('c', 'd', 7.3)]
#G.add_weighted_edges_from(elist)

nx.draw_networkx(G,  with_labels = True, node_color='yellow')

dg = nx.degree_centrality(G)
print('----degree centrality------')
print(dg)

cg = nx.closeness_centrality(G)
print('----closeness centrality------')
print(cg)

print('----betweenness centrality------')
bg = nx.betweenness_centrality(G)
print(bg)

print('----eigenvector centrality------')
eg = nx.eigenvector_centrality(G)
print(eg)
# Out:
# ----degree centrality------
# {1: 0.42857142857142855, 2: 0.42857142857142855, 3: 0.2857142857142857, 4: 0.42857142857142855, 6: 0.42857142857142855, 5: 0.42857142857142855, 7: 0.2857142857142857, 8: 0.14285714285714285}
# ----closeness centrality------
# {1: 0.4666666666666667, 2: 0.4666666666666667, 3: 0.35, 4: 0.5833333333333334, 6: 0.5833333333333334, 5: 0.4666666666666667, 7: 0.4375, 8: 0.3333333333333333}
# ----betweenness centrality------
# {1: 0.11904761904761904, 2: 0.11904761904761904, 3: 0.0, 4: 0.5714285714285714, 6: 0.5714285714285714, 5: 0.2857142857142857, 7: 0.0, 8: 0.0}
# ----eigenvector centrality------
# {1: 0.47377662231241896, 2: 0.47377662231241896, 3: 0.3477950444759982, 4: 0.4692125173435638, 6: 0.33079430754815964, 5: 0.22720419864997973, 7: 0.2048127297117387, 8: 0.08339525684417314}

# %%
# ------ A * search ------
import networkx as nx
import matplotlib.pyplot as plt 

def dist(a, b):
    (x1, y1) = a
    (x2, y2) = b
    return ((x1 - x2) ** 2 + (y1 - y2) ** 2) ** 0.5


G = nx.grid_graph(dim=[3, 3])  # nodes are two-tuples (x,y)
nx.set_edge_attributes(G, {e: e[1][0] * 2 for e in G.edges()}, "cost")
path = nx.astar_path(G, (0, 0), (2, 2), heuristic=dist, weight="cost")
length = nx.astar_path_length(G, (0, 0), (2, 2), heuristic=dist, weight="cost")
print('Path:')
print(path)
print("Path length: ") 
print(length)

pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels = True, node_color="yellow")
edge_labels = nx.get_edge_attributes(G, "cost")
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
plt.show()

# The first output represents the shortest path from point (0,0) to point (2,2). 
# The second output is the length of the shortest path.
# Out:
# Path:
# [(0, 0), (0, 1), (0, 2), (1, 2), (2, 2)]
# Path length:
# 6

# %%
G3 = nx.Graph()
G3.add_edges_from([ [0,1,{'weight':2}],
                   [1,2,{'weight':12}],
                   [2,3,{'weight':1}],
                   [3,4,{'weight':15}],
                   [4,5,{'weight':1}],
                   [3,5,{'weight':8}],
                   [5,0,{'weight':200}] ])
nx.draw(G3, with_labels = True, edge_color='grey', node_color='#74d4e8')

print(nx.dijkstra_path(G3,0,4))
# Out:
# [0, 1, 2, 3, 5, 4]

# %%
G = nx.Graph()
elist = [(1, 2), (2, 3), (2,4), (4, 5), (4, 6), (6, 7), (6, 8) ]
#nlist = nx.Graph([(0, 1), (1, 2), (2, 0)]) 
G.add_edges_from(elist)
#G.add_nodes_from(nlist)
#elist = [('a', 'b', 5.0), ('b', 'c', 3.0), ('a', 'c', 1.0), ('c', 'd', 7.3)]
#G.add_weighted_edges_from(elist)

nx.draw(G,  with_labels = True, node_color='yellow')


dg = nx.degree_centrality(G)
print('----degree centrality------')
print(dg)

cg = nx.closeness_centrality(G)
print('----closeness centrality------')
print(cg)

print('----betweenness centrality------')
bg = nx.betweenness_centrality(G)
print(bg)

print('----eigenvector centrality------')
eg = nx.eigenvector_centrality(G)
print(eg)
# Out:
# ----degree centrality------
# {1: 0.14285714285714285, 2: 0.42857142857142855, 3: 0.14285714285714285, 4: 0.42857142857142855, 5: 0.14285714285714285, 6: 0.42857142857142855, 7: 0.14285714285714285, 8: 0.14285714285714285}
# ----closeness centrality------
# {1: 0.3684210526315789, 2: 0.5384615384615384, 3: 0.3684210526315789, 4: 0.6363636363636364, 5: 0.4117647058823529, 6: 0.5384615384615384, 7: 0.3684210526315789, 8: 0.3684210526315789}
# ----betweenness centrality------
# {1: 0.0, 2: 0.5238095238095237, 3: 0.0, 4: 0.7142857142857142, 5: 0.0, 6: 0.5238095238095237, 7: 0.0, 8: 0.0}
# ----eigenvector centrality------
# {1: 0.21758193016676422, 2: 0.46470570082180035, 3: 0.21758193016676422, 4: 0.5573440694752514, 5: 0.26095445220924324, 6: 0.4647057008218003, 7: 0.2175819301667642, 8: 0.2175819301667642}

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
G.add_edges_from(
    [('A', 'B'), ('A', 'C'), ('D', 'A'), ('D', 'B'), ('B', 'D'),
     ('C', 'A'), ('C', 'B'), ('C', 'B')])

nx.draw_networkx(G,  with_labels = True, node_color='yellow')

pr = nx.pagerank(G, alpha=0.4)
pr
# Out:
# {'A': 0.243055744, 'B': 0.291666688, 'C': 0.198610944, 'D': 0.266666624}

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()
G.add_edges_from(
    [('G','A'),('D','A'),('C','A'),('B','A'),('I','B'),('B','D'),('C','B'),('D','C'),('E','D'),('F','D'),('H','C')])

nx.draw_networkx(G,  with_labels = True, node_color='yellow')

hits = nx.hits(G, max_iter = 50, normalized = True)  # 8 is maximum iteration
h,a = hits
print('authority score \n')
print(a)

print('\n \n hub score \n')
print(h)
# Out:
# authority score
#
# {'G': 0.0, 'A': 0.4728339089952555, 'D': 0.2235719054957336, 'C': 0.15179709275450537, 'B': 0.15179709275450542, 'I': 3.1384230598264715e-17, 'E': 0.0, 'F': 1.5692115299132358e-17, 'H': 0.0}
#
#
#  hub score
#
# {'G': 0.14919474392903487, 'A': 0.0, 'D': 0.1970917495198662, 'C': 0.1970917495198662, 'B': 0.2197390779025466, 'I': 0.047897005590831335, 'E': 0.07054433397351173, 'F': 0.07054433397351173, 'H': 0.047897005590831314}
# /Users/reza/anaconda3/lib/python3.10/site-packages/networkx/algorithms/link_analysis/hits_alg.py:78: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   A = nx.adjacency_matrix(G, nodelist=list(G), dtype=float)

# %%
from sklearn.cluster import SpectralClustering
import numpy as np
X = np.array([[1, 1], [2, 1], [1, 0],
               [4, 7], [3, 5], [3, 6]])
clustering = SpectralClustering(n_clusters=2,assign_labels='discretize',random_state=0).fit(X)
print(clustering.labels_)
# Out:
# [1 1 1 0 0 0]
# SpectralClustering(assign_labels='discretize', n_clusters=2, random_state=0)

# %%
import networkx as nx
import community as community_louvain
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# define the graph
edge = [('a','b'),('a','c'),('a','d'),('a','e'),('a','f'),('b','g'),('b','h'),('b','i')]
G = nx.Graph()
G.add_edges_from(edge)

# retrun partition as a dict
partition = community_louvain.best_partition(G)
print(partition)

# visualization
pos = nx.spring_layout(G)
cmap = cm.get_cmap('cividis', max(partition.values()) + 1)
nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=100,cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(G, pos, alpha=0.5)
plt.show()
# Out:
# {'a': 0, 'b': 1, 'c': 0, 'd': 0, 'e': 0, 'f': 0, 'g': 1, 'h': 1, 'i': 1}

# %%
#!pip install igraph
# !pip install cdlib
# !pip install python-igraph

! pip install libcairo2 
! pip install pipwin
! pipwin install cairocffi
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement libcairo2 (from versions: none)
# ERROR: No matching distribution found for libcairo2
# ...
# /Users/reza/anaconda3/lib/python3.10/site-packages/pipwin/command.py:66: UserWarning: Found a non Windows system. Package installation might not work.
#   warn("Found a non Windows system. Package installation might not work.")
# Package `cairocffi` found in cache
# ...
# https://download.lfd.uci.edu/pythonlibs/archived/cairocffi-1.3.0-cp310-cp310-win_amd64.whl
# cairocffi-1.3.0-cp310-cp310-win_amd64.whl
# File /Users/reza/pipwin/cairocffi-1.3.0-cp310-cp310-win_amd64.whl already exists
# ERROR: cairocffi-1.3.0-cp310-cp310-win_amd64.whl is not a supported wheel on this platform.
# Traceback (most recent call last):
#   File "/Users/reza/anaconda3/bin/pipwin", line 8, in <module>
#     sys.exit(main())
#   File "/Users/reza/anaconda3/lib/python3.10/site-packages/pipwin/command.py", line 103, in main
#     cache.install(package)
# ...

# %%
# be sure to unintall and re-install python-igraph 
from cdlib.algorithms import leiden
import igraph as ig
g = nx.karate_club_graph()
#print('original graph')
#nx.draw(g)

communities = leiden(g)
print(communities.to_json)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[34], line 2
#       1 # be sure to unintall and re-install python-igraph
# ----> 2 from cdlib.algorithms import leiden
#       3 import igraph as ig
#       4 g = nx.karate_club_graph()
#
# File ~/anaconda3/lib/python3.10/site-packages/cdlib/__init__.py:1
# ----> 1 from cdlib.classes.node_clustering import NodeClustering
#       2 from cdlib.classes.edge_clustering import EdgeClustering
#       3 from cdlib.classes.fuzzy_node_clustering import FuzzyNodeClustering
#
# File ~/anaconda3/lib/python3.10/site-packages/cdlib/classes/__init__.py:1
# ----> 1 from .node_clustering import NodeClustering
#       2 from .edge_clustering import EdgeClustering
#       3 from .fuzzy_node_clustering import FuzzyNodeClustering
#
# File ~/anaconda3/lib/python3.10/site-packages/cdlib/classes/node_clustering.py:2
# ...

# %%
import igraph as ig
import leidenalg as la
G = ig.Graph.Famous('Zachary')
partition = la.find_partition(G, la.ModularityVertexPartition)
print(partition)

#ig.plot(partition)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 import igraph as ig
#       2 import leidenalg as la
#       3 G = ig.Graph.Famous('Zachary')
#
# File ~/anaconda3/lib/python3.10/site-packages/igraph/__init__.py:103
#      88 from igraph.basic import (
#      89     _add_edge,
#      90     _add_edges,
#    (...)
#      96     _as_undirected,
#      97 )
#      98 from igraph.bipartite import (
#      99     _maximum_bipartite_matching,
#     100     _bipartite_projection,
#     101     _bipartite_projection_size,
#     102 )
# --> 103 from igraph.community import (
#     104     _community_fastgreedy,
#     105     _community_infomap,
#     106     _community_leading_eigenvector_naive,
#     107     _community_leading_eigenvector,
#     108     _community_label_propagation,
#     109     _community_multilevel,
# ...
