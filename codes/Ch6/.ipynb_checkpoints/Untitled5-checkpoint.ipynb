# %%
import requests
from bs4 import BeautifulSoup

print("Beautiful SOAP web scrapping test sample")
# http://www.asimovonline.com/asimov_home_page.html
page = requests.get('https://en.wikipedia.org/wiki/Isaac_Asimov')

# Create a BeautifulSoup object to parse html
soup = BeautifulSoup(page.text, 'html.parser')

# find a class on higher level
mycls = soup.find(class_= "mw-body") # mw-body-content "mw-body"
#print(mycls)

#search inside the class
desc = mycls.find_all("tbody")
print(desc)
# Out:
# Beautiful SOAP web scrapping test sample
# ...

# %%
import requests
from bs4 import BeautifulSoup

print("Beautiful SOAP web scrapping test sample")
# http://www.asimovonline.com/asimov_home_page.html
page = requests.get('view-source:https://www.instagram.com/gigadgets')

# Create a BeautifulSoup object to parse html
soup = BeautifulSoup(page.text, 'html.parser')

# find a class on higher level
mycls = soup.find(class_= "head") # mw-body-content "mw-body"
print(mycls)
# Out:
# Beautiful SOAP web scrapping test sample
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# <ipython-input-2-df2a2125cd08> in <module>
#       4 print("Beautiful SOAP web scrapping test sample")
#       5 # http://www.asimovonline.com/asimov_home_page.html
# ----> 6 page = requests.get('view-source:https://www.instagram.com/gigadgets')
#       7
#       8 # Create a BeautifulSoup object to parse html
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ...
