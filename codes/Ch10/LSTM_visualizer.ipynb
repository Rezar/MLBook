# %%
#! pip install --upgrade keras
# run this command in terminal: ! conda install cudnn

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
import re

# Imports for visualisations
from IPython.display import HTML as html_print
from IPython.display import display
import keras.backend as K

# %%
# Read data
filename = "ggmarques.txt"
raw_text = open(filename, 'r', encoding='utf-8').read()
raw_text = re.sub(r'[ ]+', ' ', raw_text)

# create mapping of unique chars to integers
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

n_chars = len(raw_text)
n_vocab = len(chars)

# %%
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []

for i in range(0, n_chars - seq_length, 1):
    seq_in = raw_text[i:i + seq_length]
    seq_out = raw_text[i + seq_length]
    dataX.append([char_to_int[char] for char in seq_in])
    dataY.append(char_to_int[seq_out])

n_patterns = len(dataX)
print("Total Patterns: ", n_patterns)

# reshape X to be [samples, time steps, features]
X = np.reshape(dataX, (n_patterns, seq_length, 1))

# normalize
X = X / float(n_vocab)

# one hot encode the output variable
y = np_utils.to_categorical(dataY)

# define the checkpoint
filepath="weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
# Out:
# Total Patterns:  832410

# %%
# define the LSTM model
model = Sequential()

model.add(LSTM(512, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.5))

model.add(LSTM(512))
model.add(Dropout(0.5))

model.add(Dense(y.shape[1], activation='softmax'))

# build the LSTM model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

#Train the built model
#model.fit(X, y, epochs=300, batch_size=2048 , callbacks=callbacks_list)
model.fit(X, y, epochs=300, batch_size=2048)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 512)          1052672
# _________________________________________________________________
# dropout (Dropout)            (None, 100, 512)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 512)               2099200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 85)                43605
# =================================================================
# Total params: 3,195,477
# Trainable params: 3,195,477
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
#   2/407 [..............................] - ETA: 1:49 - loss: 4.3651 - accuracy: 0.1035WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1291s vs `on_train_batch_end` time: 0.2243s). Check your callbacks.
# 407/407 [==============================] - 146s 358ms/step - loss: 3.1063 - accuracy: 0.1673
# Epoch 2/300
# 407/407 [==============================] - 147s 360ms/step - loss: 2.8928 - accuracy: 0.1973
# Epoch 3/300
# 407/407 [==============================] - 147s 360ms/step - loss: 2.7871 - accuracy: 0.2163
# Epoch 4/300
# 407/407 [==============================] - 147s 361ms/step - loss: 2.7345 - accuracy: 0.2300
# Epoch 5/300
# 407/407 [==============================] - 147s 361ms/step - loss: 2.6800 - accuracy: 0.2435
# Epoch 6/300
# 407/407 [==============================] - 148s 363ms/step - loss: 2.6254 - accuracy: 0.2591
# Epoch 7/300
# 407/407 [==============================] - 147s 361ms/step - loss: 2.5813 - accuracy: 0.2728
# Epoch 8/300
# 407/407 [==============================] - 147s 361ms/step - loss: 2.5376 - accuracy: 0.2836
# Epoch 9/300
# 407/407 [==============================] - 147s 361ms/step - loss: 2.4912 - accuracy: 0.2934
# Epoch 10/300
# 407/407 [==============================] - 147s 361ms/step - loss: 2.4419 - accuracy: 0.3054
# Epoch 11/300
# 407/407 [==============================] - 147s 362ms/step - loss: 2.3904 - accuracy: 0.3194
# Epoch 12/300
# 407/407 [==============================] - 147s 361ms/step - loss: 2.3356 - accuracy: 0.3344
# Epoch 13/300
# 407/407 [==============================] - 147s 362ms/step - loss: 2.2848 - accuracy: 0.3479
# Epoch 14/300
# 407/407 [==============================] - 148s 363ms/step - loss: 2.2334 - accuracy: 0.3619
# Epoch 15/300
# 407/407 [==============================] - 147s 362ms/step - loss: 2.1889 - accuracy: 0.3739
# Epoch 16/300
# 407/407 [==============================] - 147s 362ms/step - loss: 2.1362 - accuracy: 0.3895
# Epoch 17/300
# 407/407 [==============================] - 148s 363ms/step - loss: 2.0922 - accuracy: 0.4017
# Epoch 18/300
# 407/407 [==============================] - 148s 363ms/step - loss: 2.0573 - accuracy: 0.4109
# Epoch 19/300
# 407/407 [==============================] - 147s 362ms/step - loss: 2.0301 - accuracy: 0.4182
# Epoch 20/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.9945 - accuracy: 0.4278
# Epoch 21/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.9641 - accuracy: 0.4359
# Epoch 22/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.9367 - accuracy: 0.4432
# Epoch 23/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.9118 - accuracy: 0.4492
# Epoch 24/300
# 407/407 [==============================] - 147s 362ms/step - loss: 1.8904 - accuracy: 0.4550
# Epoch 25/300
# 407/407 [==============================] - 147s 362ms/step - loss: 1.8651 - accuracy: 0.4613
# Epoch 26/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.8445 - accuracy: 0.4673
# Epoch 27/300
# 407/407 [==============================] - 147s 362ms/step - loss: 1.8252 - accuracy: 0.4724
# Epoch 28/300
# 407/407 [==============================] - 147s 362ms/step - loss: 1.8071 - accuracy: 0.4767
# Epoch 29/300
# 407/407 [==============================] - 147s 362ms/step - loss: 1.7874 - accuracy: 0.4826
# Epoch 30/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.7724 - accuracy: 0.4861
# Epoch 31/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.7547 - accuracy: 0.4907
# Epoch 32/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.7390 - accuracy: 0.4945
# Epoch 33/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.7249 - accuracy: 0.4991
# Epoch 34/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.7101 - accuracy: 0.5028
# Epoch 35/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.6978 - accuracy: 0.5058
# Epoch 36/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.6869 - accuracy: 0.5089
# Epoch 37/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.6728 - accuracy: 0.5120
# Epoch 38/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.6630 - accuracy: 0.5146
# Epoch 39/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.6526 - accuracy: 0.5172
# Epoch 40/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.6470 - accuracy: 0.5188
# Epoch 41/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.6295 - accuracy: 0.5236
# Epoch 42/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.6554 - accuracy: 0.5168
# Epoch 43/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.6150 - accuracy: 0.5272
# Epoch 44/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.6116 - accuracy: 0.5280
# Epoch 45/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.6014 - accuracy: 0.5299
# Epoch 46/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.5929 - accuracy: 0.5323
# Epoch 47/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.5861 - accuracy: 0.5343
# Epoch 48/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.5775 - accuracy: 0.5361
# Epoch 49/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.5724 - accuracy: 0.5377
# Epoch 50/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.5637 - accuracy: 0.5399
# Epoch 51/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.5572 - accuracy: 0.5413
# Epoch 52/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.5511 - accuracy: 0.5429
# Epoch 53/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.5432 - accuracy: 0.5447
# Epoch 54/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.5409 - accuracy: 0.5454
# Epoch 55/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.5299 - accuracy: 0.5479
# Epoch 56/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.5275 - accuracy: 0.5488
# Epoch 57/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.5200 - accuracy: 0.5503
# Epoch 58/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.5160 - accuracy: 0.5513
# Epoch 59/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.5084 - accuracy: 0.5532
# Epoch 60/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.5014 - accuracy: 0.5553
# Epoch 61/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4977 - accuracy: 0.5559
# Epoch 62/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4877 - accuracy: 0.5588
# Epoch 63/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4898 - accuracy: 0.5579
# Epoch 64/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4801 - accuracy: 0.5604
# Epoch 65/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4787 - accuracy: 0.5612
# Epoch 66/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4737 - accuracy: 0.5619
# Epoch 67/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4677 - accuracy: 0.5636
# Epoch 68/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4684 - accuracy: 0.5640
# Epoch 69/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4603 - accuracy: 0.5651
# Epoch 70/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4542 - accuracy: 0.5671
# Epoch 71/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4473 - accuracy: 0.5686
# Epoch 72/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4463 - accuracy: 0.5687
# Epoch 73/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4391 - accuracy: 0.5708
# Epoch 74/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4379 - accuracy: 0.5711
# Epoch 75/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4325 - accuracy: 0.5720
# Epoch 76/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4289 - accuracy: 0.5734
# Epoch 77/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4302 - accuracy: 0.5726
# Epoch 78/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4203 - accuracy: 0.5750
# Epoch 79/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4196 - accuracy: 0.5753
# Epoch 80/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4128 - accuracy: 0.5773
# Epoch 81/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4162 - accuracy: 0.5760
# Epoch 82/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4071 - accuracy: 0.5785
# Epoch 83/300
# 407/407 [==============================] - 148s 364ms/step - loss: 2.1483 - accuracy: 0.3960
# Epoch 84/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.5202 - accuracy: 0.5501
# Epoch 85/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.4431 - accuracy: 0.5696
# Epoch 86/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4185 - accuracy: 0.5762
# Epoch 87/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4091 - accuracy: 0.5784
# Epoch 88/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3983 - accuracy: 0.5810
# Epoch 89/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.3958 - accuracy: 0.5811
# Epoch 90/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3891 - accuracy: 0.5829
# Epoch 91/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3920 - accuracy: 0.5826
# Epoch 92/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3842 - accuracy: 0.5846
# Epoch 93/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3830 - accuracy: 0.5848
# Epoch 94/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3851 - accuracy: 0.5840
# Epoch 95/300
# 407/407 [==============================] - 149s 366ms/step - loss: 1.3819 - accuracy: 0.5851
# Epoch 96/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3824 - accuracy: 0.5850
# Epoch 97/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.3801 - accuracy: 0.5849
# Epoch 98/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.3812 - accuracy: 0.5846
# Epoch 99/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.3748 - accuracy: 0.5870
# Epoch 100/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.3736 - accuracy: 0.5869
# Epoch 101/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.3792 - accuracy: 0.5861
# Epoch 102/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.4722 - accuracy: 0.5651
# Epoch 103/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4340 - accuracy: 0.5708
# Epoch 104/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4199 - accuracy: 0.5748
# Epoch 105/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4075 - accuracy: 0.5789
# Epoch 106/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3984 - accuracy: 0.5811
# Epoch 107/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.4020 - accuracy: 0.5798
# Epoch 108/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3816 - accuracy: 0.5850
# Epoch 109/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3691 - accuracy: 0.5885
# Epoch 110/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3586 - accuracy: 0.5910
# Epoch 111/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3568 - accuracy: 0.5918
# Epoch 112/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.3578 - accuracy: 0.5912
# Epoch 113/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3533 - accuracy: 0.5922
# Epoch 114/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.3543 - accuracy: 0.5919
# Epoch 115/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3520 - accuracy: 0.5926
# Epoch 116/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3454 - accuracy: 0.5938
# Epoch 117/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3439 - accuracy: 0.5942
# Epoch 118/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.3429 - accuracy: 0.5953
# Epoch 119/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3393 - accuracy: 0.5953
# Epoch 120/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3377 - accuracy: 0.5960
# Epoch 121/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.3371 - accuracy: 0.5961
# Epoch 122/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3328 - accuracy: 0.5971
# Epoch 123/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3326 - accuracy: 0.5973
# Epoch 124/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3308 - accuracy: 0.5981
# Epoch 125/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.3252 - accuracy: 0.5990
# Epoch 126/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.3252 - accuracy: 0.5988
# Epoch 127/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3291 - accuracy: 0.5980
# Epoch 128/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3204 - accuracy: 0.6003
# Epoch 129/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3211 - accuracy: 0.5998
# Epoch 130/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.3163 - accuracy: 0.6016
# Epoch 131/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.3186 - accuracy: 0.6010
# Epoch 132/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.3148 - accuracy: 0.6018
# Epoch 133/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3142 - accuracy: 0.6020
# Epoch 134/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3117 - accuracy: 0.6022
# Epoch 135/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.3096 - accuracy: 0.6027
# Epoch 136/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.3129 - accuracy: 0.6021
# Epoch 137/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3054 - accuracy: 0.6042
# Epoch 138/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3041 - accuracy: 0.6039
# Epoch 139/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3086 - accuracy: 0.6035
# Epoch 140/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3005 - accuracy: 0.6049
# Epoch 141/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2977 - accuracy: 0.6060
# Epoch 142/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3034 - accuracy: 0.6042
# Epoch 143/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3026 - accuracy: 0.6045
# Epoch 144/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2920 - accuracy: 0.6072
# Epoch 145/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2931 - accuracy: 0.6067
# Epoch 146/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2974 - accuracy: 0.6063
# Epoch 147/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2897 - accuracy: 0.6079
# Epoch 148/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2877 - accuracy: 0.6085
# Epoch 149/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.2904 - accuracy: 0.6075
# Epoch 150/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2907 - accuracy: 0.6079
# Epoch 151/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2852 - accuracy: 0.6091
# Epoch 152/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2832 - accuracy: 0.6097
# Epoch 153/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.2891 - accuracy: 0.6084
# Epoch 154/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.2838 - accuracy: 0.6097
# Epoch 155/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.2801 - accuracy: 0.6105
# Epoch 156/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2769 - accuracy: 0.6118
# Epoch 157/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2820 - accuracy: 0.6096
# Epoch 158/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2752 - accuracy: 0.6116
# Epoch 159/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2718 - accuracy: 0.6125
# Epoch 160/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2801 - accuracy: 0.6100
# Epoch 161/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2718 - accuracy: 0.6123
# Epoch 162/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2703 - accuracy: 0.6122
# Epoch 163/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2702 - accuracy: 0.6128
# Epoch 164/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2704 - accuracy: 0.6124
# Epoch 165/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.2707 - accuracy: 0.6127
# Epoch 166/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2664 - accuracy: 0.6132
# Epoch 167/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2665 - accuracy: 0.6137
# Epoch 168/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.2666 - accuracy: 0.6134
# Epoch 169/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2642 - accuracy: 0.6146
# Epoch 170/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2594 - accuracy: 0.6156
# Epoch 171/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2674 - accuracy: 0.6129
# Epoch 172/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2587 - accuracy: 0.6155
# Epoch 173/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2630 - accuracy: 0.6144
# Epoch 174/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2560 - accuracy: 0.6162
# Epoch 175/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2578 - accuracy: 0.6164
# Epoch 176/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2618 - accuracy: 0.6149
# Epoch 177/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2558 - accuracy: 0.6161
# Epoch 178/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2557 - accuracy: 0.6163
# Epoch 179/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2539 - accuracy: 0.6169
# Epoch 180/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2526 - accuracy: 0.6173
# Epoch 181/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2763 - accuracy: 0.6114
# Epoch 182/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2547 - accuracy: 0.6167
# Epoch 183/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2471 - accuracy: 0.6185
# Epoch 184/300
# 407/407 [==============================] - 149s 366ms/step - loss: 1.2853 - accuracy: 0.6086
# Epoch 185/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2514 - accuracy: 0.6174
# Epoch 186/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2437 - accuracy: 0.6195
# Epoch 187/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2452 - accuracy: 0.6195
# Epoch 188/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2425 - accuracy: 0.6201
# Epoch 189/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2453 - accuracy: 0.6196
# Epoch 191/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2407 - accuracy: 0.6205
# Epoch 192/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2393 - accuracy: 0.6203
# Epoch 193/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2386 - accuracy: 0.6210
# Epoch 194/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.2408 - accuracy: 0.6203
# Epoch 195/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2376 - accuracy: 0.6207
# Epoch 196/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2431 - accuracy: 0.6198
# Epoch 197/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2383 - accuracy: 0.6206
# Epoch 198/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2356 - accuracy: 0.6218
# Epoch 199/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2412 - accuracy: 0.6198
# Epoch 200/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2364 - accuracy: 0.6212
# Epoch 201/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.2352 - accuracy: 0.6219
# Epoch 202/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2407 - accuracy: 0.6203
# Epoch 203/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.8290 - accuracy: 0.4845
# Epoch 204/300
# 407/407 [==============================] - 148s 364ms/step - loss: 2.1309 - accuracy: 0.3867
# Epoch 205/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.4643 - accuracy: 0.5631
# Epoch 206/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.3122 - accuracy: 0.6021
# Epoch 207/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2636 - accuracy: 0.6153
# Epoch 208/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2442 - accuracy: 0.6199
# Epoch 209/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2322 - accuracy: 0.6231
# Epoch 210/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.2326 - accuracy: 0.6229
# Epoch 211/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2259 - accuracy: 0.6243
# Epoch 212/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2272 - accuracy: 0.6241
# Epoch 213/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2239 - accuracy: 0.6246
# Epoch 214/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2249 - accuracy: 0.6241
# Epoch 215/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2269 - accuracy: 0.6237
# Epoch 216/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2271 - accuracy: 0.6239
# Epoch 217/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2293 - accuracy: 0.6236
# Epoch 218/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2279 - accuracy: 0.6231
# Epoch 219/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2374 - accuracy: 0.6213
# Epoch 220/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2241 - accuracy: 0.6245
# Epoch 222/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2244 - accuracy: 0.6236
# Epoch 223/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.2236 - accuracy: 0.6244
# Epoch 224/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2276 - accuracy: 0.6238
# Epoch 225/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2203 - accuracy: 0.6252
# Epoch 226/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2197 - accuracy: 0.6256
# Epoch 227/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.2199 - accuracy: 0.6254
# Epoch 228/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2188 - accuracy: 0.6256
# Epoch 229/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2163 - accuracy: 0.6264
# Epoch 230/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2167 - accuracy: 0.6263
# Epoch 231/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2148 - accuracy: 0.6262
# Epoch 232/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.5996 - accuracy: 0.5322
# Epoch 233/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.3093 - accuracy: 0.6022
# Epoch 234/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2321 - accuracy: 0.6228
# Epoch 235/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2143 - accuracy: 0.6272
# Epoch 236/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2134 - accuracy: 0.6278
# Epoch 237/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2057 - accuracy: 0.6297
# Epoch 238/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2042 - accuracy: 0.6297
# Epoch 239/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2029 - accuracy: 0.6300
# Epoch 240/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2032 - accuracy: 0.6302
# Epoch 241/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2080 - accuracy: 0.6282
# Epoch 242/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2096 - accuracy: 0.6281
# Epoch 243/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2084 - accuracy: 0.6284
# Epoch 244/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.2061 - accuracy: 0.6289
# Epoch 245/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2044 - accuracy: 0.6299
# Epoch 246/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2056 - accuracy: 0.6287
# Epoch 247/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2072 - accuracy: 0.6289
# Epoch 248/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2080 - accuracy: 0.6287
# Epoch 249/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2082 - accuracy: 0.6281
# Epoch 250/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2024 - accuracy: 0.6302
# Epoch 251/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2053 - accuracy: 0.6289
# Epoch 252/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2077 - accuracy: 0.6287
# Epoch 253/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2027 - accuracy: 0.6302
# Epoch 254/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.2022 - accuracy: 0.6294
# Epoch 255/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2005 - accuracy: 0.6308
# Epoch 256/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2033 - accuracy: 0.6298
# Epoch 257/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2008 - accuracy: 0.6304
# Epoch 258/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2100 - accuracy: 0.6277
# Epoch 259/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2028 - accuracy: 0.6300
# Epoch 260/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2209 - accuracy: 0.6250
# Epoch 261/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.2234 - accuracy: 0.6246
# Epoch 262/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1968 - accuracy: 0.6309
# Epoch 263/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1930 - accuracy: 0.6324
# Epoch 264/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1915 - accuracy: 0.6330
# Epoch 265/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1924 - accuracy: 0.6324
# Epoch 266/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.1939 - accuracy: 0.6322
# Epoch 267/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.1968 - accuracy: 0.6313
# Epoch 268/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1947 - accuracy: 0.6323
# Epoch 269/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1915 - accuracy: 0.6325
# Epoch 270/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1914 - accuracy: 0.6325
# Epoch 271/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1918 - accuracy: 0.6326
# Epoch 272/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1975 - accuracy: 0.6308
# Epoch 273/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1922 - accuracy: 0.6321
# Epoch 274/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1960 - accuracy: 0.6318
# Epoch 275/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1886 - accuracy: 0.6335
# Epoch 276/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.1900 - accuracy: 0.6328
# Epoch 277/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.1885 - accuracy: 0.6336
# Epoch 278/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.1894 - accuracy: 0.6333
# Epoch 279/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.1884 - accuracy: 0.6337
# Epoch 280/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.1922 - accuracy: 0.6328
# Epoch 281/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.2785 - accuracy: 0.6113
# Epoch 282/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.1950 - accuracy: 0.6315
# Epoch 283/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.1860 - accuracy: 0.6339
# Epoch 284/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.1839 - accuracy: 0.6345
# Epoch 285/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.1826 - accuracy: 0.6348
# Epoch 286/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.1806 - accuracy: 0.6352
# Epoch 287/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.1866 - accuracy: 0.6341
# Epoch 288/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.1834 - accuracy: 0.6347
# Epoch 289/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1861 - accuracy: 0.6344
# Epoch 290/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1941 - accuracy: 0.6323
# Epoch 291/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1841 - accuracy: 0.6350
# Epoch 292/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.1831 - accuracy: 0.6350
# Epoch 293/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1787 - accuracy: 0.6361
# Epoch 294/300
# 407/407 [==============================] - 148s 363ms/step - loss: 1.1794 - accuracy: 0.6358
# Epoch 295/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.1801 - accuracy: 0.6359
# Epoch 296/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.1792 - accuracy: 0.6355
# Epoch 297/300
# 407/407 [==============================] - 148s 365ms/step - loss: 1.1792 - accuracy: 0.6355
# Epoch 298/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.1804 - accuracy: 0.6358
# Epoch 299/300
# 407/407 [==============================] - 149s 365ms/step - loss: 1.1907 - accuracy: 0.6328
# Epoch 300/300
# 407/407 [==============================] - 148s 364ms/step - loss: 1.1759 - accuracy: 0.6368

# %%
#---- Since it takes a long time, we could save the model and next time read the saved model
# serialize model to JSON
model_json = model.to_json()
with open("LSTM1-marqoues-300epoch.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("LSTM1-marqoues-300epoch-weights.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
''' load model from the Github
json_file = open('sample_LSTM1-100epoch.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
'''
# Out:
# ' load model from the Github\njson_file = open(\'sample_LSTM1-100epoch.json\', \'r\')\nloaded_model_json = json_file.read()\njson_file.close()\nloaded_model = model_from_json(loaded_model_json)\n# load weights into new model\nloaded_model.load_weights("model.h5")\nprint("Loaded model from disk")\n'

# %%
#--------- Now the model is ready and we start to focus on Visualization -----------

# Get output from intermediate layer to visualize activations

# 3rd layer is LSTM layer with output shape (Batch_Size, 512)
lstm = model.layers[2]
print (lstm.output)

attn_func = K.function(inputs = [model.inputs[0]],  
                       outputs = [lstm.output])

# get html element
def cstr(s, color='black'):
    if s == ' ':
        return "<text style=color:#000;padding-left:10px;background-color:{}> </text>".format(color, s)
    else:
        return "<text style=color:#000;background-color:{}>{} </text>".format(color, s)

# print html
def print_color(t):
    display(html_print(''.join([cstr(ti, color=ci) for ti,ci in t])))

# get appropriate color for value
def get_clr(value):
    colors = ['#85c2e1', '#89c4e2', '#95cae5', '#99cce6', '#a1d0e8'
        '#b2d9ec', '#baddee', '#c2e1f0', '#eff7fb', '#f9e8e8',
        '#f9e8e8', '#f9d4d4', '#f9bdbd', '#f8a8a8', '#f68f8f',
        '#f47676', '#f45f5f', '#f34343', '#f33b3b', '#f42e2e']
    value = int((value * 100) / 5)
    return colors[value]

# sigmoid function
def sigmoid(x):
    z = 1/(1 + np.exp(-x)) 
    return z
# Out:
# Tensor("lstm_1/PartitionedCall:0", shape=(None, 512), dtype=float32)

# %%
def visualize(output_values, result_list, cell_no):
    print("\nCell Number:", cell_no, "\n")
    text_colours = []
    for i in range(len(output_values)):
        text = (result_list[i], get_clr(output_values[i][cell_no]))
        text_colours.append(text)
    print_color(text_colours)
    
# Get Predictions from random sequence
def get_predictions(data):
    start = np.random.randint(0, len(data)-1)
    pattern = data[start]
    result_list, output_values = [], []
    print("Seed:")
    print("\"" + ''.join([int_to_char[value] for value in pattern]) + "\"")
    print("\nGenerated:")

    for i in range(1000):
        # Reshaping input array for predicting next character
        x = np.reshape(pattern, (1, len(pattern), 1))
        x = x / float(n_vocab)

        # Prediction
        prediction = model.predict(x, verbose=0)

        # LSTM Activations
        output = attn_func([x])[0][0]
        output = sigmoid(output)
        output_values.append(output)

        # Predicted Character
        index = np.argmax(prediction)
        result = int_to_char[index]

        # Preparing input for next character
        seq_in = [int_to_char[value] for value in pattern]
        pattern.append(index)
        pattern = pattern[1:len(pattern)]

        # Saving generated characters
        result_list.append(result)
    return output_values, result_list

# %%
output_values, result_list = get_predictions(dataX)

for cell_no in [500, 435, 463, 470, 475, 480, 350, 400]:
    visualize(output_values, result_list, cell_no)
# Out:
# Seed:
# " would never marry a man who was so simple that he had
# wasted almost an hour and even went without "
#
# Generated:
#
# Cell Number: 500
# <text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f8a8a8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;background-color:#c2e1f0>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#f8a8a8>o </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>p </text><text style=color:#000;background-color:#f68f8f>r </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9d4d4>c </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#c2e1f0>a </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#baddee>i </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9bdbd>f </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9bdbd>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;background-color:#f9bdbd>a </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#eff7fb>i </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>y </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9bdbd>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#c2e1f0>e </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>
#  </text><text style=color:#000;background-color:#eff7fb>p </text><text style=color:#000;background-color:#f68f8f>a </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#c2e1f0>t </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f8a8a8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f8a8a8>o </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f8a8a8>h </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>c </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9bdbd>a </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;padding-left:10px;background-color:#baddee> </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;padding-left:10px;background-color:#f9bdbd> </text><text style=color:#000;background-color:#c2e1f0>m </text><text style=color:#000;background-color:#f68f8f>a </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;padding-left:10px;background-color:#c2e1f0> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f8a8a8>h </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>w </text><text style=color:#000;background-color:#f9bdbd>a </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;padding-left:10px;background-color:#c2e1f0> </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;background-color:#f9bdbd>o </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>p </text><text style=color:#000;background-color:#f68f8f>u </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>g </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;background-color:#f9bdbd>o </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>d ...
# Cell Number: 200
# <text style=color:#000;background-color:#f47676>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9bdbd> </text><text style=color:#000;background-color:#f47676>a </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;background-color:#f8a8a8>d </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>p </text><text style=color:#000;background-color:#f9d4d4>r </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>c </text><text style=color:#000;background-color:#f9d4d4>l </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>f </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f47676>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f68f8f>f </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f68f8f>m </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f9d4d4>l </text><text style=color:#000;background-color:#f9d4d4>y </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f8a8a8>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f9d4d4>d </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>
#  </text><text style=color:#000;background-color:#f9d4d4>p </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9d4d4>r </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>f </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f68f8f>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f68f8f>w </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>r </text><text style=color:#000;background-color:#f9d4d4>l </text><text style=color:#000;background-color:#f9d4d4>d </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>w </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f9d4d4>c </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>w </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9bdbd>t </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f47676>m </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f8a8a8>n </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>w </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f47676>w </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9bdbd>s </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>p </text><text style=color:#000;background-color:#f9d4d4>u </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f9d4d4>r </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>g </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9bdbd>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f8a8a8>f </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>r </text><text style=color:#000;background-color:#f9d4d4>d ...
# Cell Number: 435
# <text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#baddee>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#eff7fb>n </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#baddee>o </text><text style=color:#000;background-color:#c2e1f0>s </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>p </text><text style=color:#000;background-color:#baddee>r </text><text style=color:#000;background-color:#baddee>o </text><text style=color:#000;background-color:#f9e8e8>c </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#baddee>f </text><text style=color:#000;padding-left:10px;background-color:#baddee> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#eff7fb>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;background-color:#baddee>a </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>y </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#baddee>h </text><text style=color:#000;background-color:#baddee>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#baddee>e </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#c2e1f0>e </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>
#  </text><text style=color:#000;background-color:#f9e8e8>p </text><text style=color:#000;background-color:#c2e1f0>a </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#eff7fb>f </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#eff7fb>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#baddee>o </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#baddee>h </text><text style=color:#000;background-color:#baddee>i </text><text style=color:#000;background-color:#f9e8e8>c </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#baddee>a </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;background-color:#c2e1f0>o </text><text style=color:#000;background-color:#eff7fb>t </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;padding-left:10px;background-color:#eff7fb> </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#eff7fb>a </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9bdbd>h </text><text style=color:#000;background-color:#f8a8a8>o </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>w </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#c2e1f0>o </text><text style=color:#000;padding-left:10px;background-color:#baddee> </text><text style=color:#000;background-color:#f9e8e8>p </text><text style=color:#000;background-color:#baddee>u </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>g </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f8a8a8>h </text><text style=color:#000;background-color:#f68f8f>e </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;background-color:#eff7fb>o </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>d ...
# Cell Number: 463
# <text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#eff7fb> </text><text style=color:#000;background-color:#eff7fb>a </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#eff7fb>p </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>c </text><text style=color:#000;background-color:#eff7fb>l </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#eff7fb>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#eff7fb> </text><text style=color:#000;background-color:#eff7fb>f </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#eff7fb>m </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>y </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#eff7fb>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#eff7fb>t </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#eff7fb> </text><text style=color:#000;background-color:#c2e1f0>
#  </text><text style=color:#000;background-color:#f9e8e8>p </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#eff7fb>t </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#eff7fb>o </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#c2e1f0>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#c2e1f0> </text><text style=color:#000;background-color:#c2e1f0>w </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#eff7fb>r </text><text style=color:#000;background-color:#c2e1f0>l </text><text style=color:#000;background-color:#c2e1f0>d </text><text style=color:#000;padding-left:10px;background-color:#c2e1f0> </text><text style=color:#000;background-color:#c2e1f0>w </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#eff7fb>i </text><text style=color:#000;background-color:#f9e8e8>c </text><text style=color:#000;background-color:#eff7fb>h </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#eff7fb>w </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#c2e1f0>n </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#c2e1f0>m </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#c2e1f0>n </text><text style=color:#000;padding-left:10px;background-color:#eff7fb> </text><text style=color:#000;background-color:#c2e1f0>w </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#baddee>w </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#eff7fb>s </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#c2e1f0>s </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>p </text><text style=color:#000;background-color:#f9e8e8>u </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#eff7fb>o </text><text style=color:#000;background-color:#c2e1f0>g </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#c2e1f0>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#c2e1f0>f </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#eff7fb>r </text><text style=color:#000;background-color:#f9e8e8>d ...
# Cell Number: 470
# <text style=color:#000;background-color:#baddee>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#baddee> </text><text style=color:#000;background-color:#baddee>a </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#eff7fb>m </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#c2e1f0>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#eff7fb>p </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#eff7fb>o </text><text style=color:#000;background-color:#f9e8e8>c </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;padding-left:10px;background-color:#baddee> </text><text style=color:#000;background-color:#c2e1f0>o </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;padding-left:10px;background-color:#baddee> </text><text style=color:#000;background-color:#baddee>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#c2e1f0> </text><text style=color:#000;background-color:#baddee>f </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>y </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#baddee>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#eff7fb> </text><text style=color:#000;background-color:#baddee>s </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#eff7fb>s </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>
#  </text><text style=color:#000;background-color:#f9e8e8>p </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#c2e1f0>r </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#c2e1f0>o </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;padding-left:10px;background-color:#baddee> </text><text style=color:#000;background-color:#c2e1f0>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#c2e1f0> </text><text style=color:#000;background-color:#baddee>w </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#eff7fb>d </text><text style=color:#000;padding-left:10px;background-color:#c2e1f0> </text><text style=color:#000;background-color:#c2e1f0>w </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#baddee>i </text><text style=color:#000;background-color:#c2e1f0>c </text><text style=color:#000;background-color:#baddee>h </text><text style=color:#000;padding-left:10px;background-color:#c2e1f0> </text><text style=color:#000;background-color:#baddee>w </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;padding-left:10px;background-color:#baddee> </text><text style=color:#000;background-color:#baddee>n </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#c2e1f0>t </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#baddee>a </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#baddee>m </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;padding-left:10px;background-color:#eff7fb> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#eff7fb>o </text><text style=color:#000;padding-left:10px;background-color:#eff7fb> </text><text style=color:#000;background-color:#c2e1f0>w </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;padding-left:10px;background-color:#baddee> </text><text style=color:#000;background-color:#baddee>s </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#c2e1f0>p </text><text style=color:#000;background-color:#f9e8e8>u </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#eff7fb>o </text><text style=color:#000;background-color:#f9e8e8>g </text><text style=color:#000;padding-left:10px;background-color:#c2e1f0> </text><text style=color:#000;background-color:#eff7fb>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#eff7fb>e </text><text style=color:#000;padding-left:10px;background-color:#baddee> </text><text style=color:#000;background-color:#baddee>f </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>d ...
# Cell Number: 475
# <text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#c2e1f0> </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;background-color:#f9d4d4>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>p </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>c </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#c2e1f0>n </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9bdbd>f </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#eff7fb>y </text><text style=color:#000;padding-left:10px;background-color:#f68f8f> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f8a8a8>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>
#  </text><text style=color:#000;background-color:#f9d4d4>p </text><text style=color:#000;background-color:#f9bdbd>a </text><text style=color:#000;background-color:#f9d4d4>r </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;padding-left:10px;background-color:#f8a8a8> </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9d4d4>f </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f8a8a8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#eff7fb>h </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>c </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9bdbd>h </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>p </text><text style=color:#000;background-color:#f9e8e8>u </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#c2e1f0>g </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>d ...
# Cell Number: 480
# <text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9bdbd> </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;background-color:#f9d4d4>d </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f47676> </text><text style=color:#000;background-color:#f8a8a8>p </text><text style=color:#000;background-color:#f9d4d4>r </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>c </text><text style=color:#000;background-color:#f9d4d4>l </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f68f8f>t </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9d4d4>f </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#eff7fb>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f9bdbd>l </text><text style=color:#000;background-color:#f9d4d4>y </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f8a8a8> </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f8a8a8>d </text><text style=color:#000;padding-left:10px;background-color:#f9bdbd> </text><text style=color:#000;background-color:#f8a8a8>
# ...
# Cell Number: 350
# <text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>p </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>c </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#baddee>o </text><text style=color:#000;background-color:#baddee>n </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>f </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>y </text><text style=color:#000;padding-left:10px;background-color:#baddee> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#baddee>e </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>
#  </text><text style=color:#000;background-color:#f9d4d4>p </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>w </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#c2e1f0>r </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>c </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>w </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>p </text><text style=color:#000;background-color:#f9e8e8>u </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>i </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>g </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9e8e8>h </text><text style=color:#000;background-color:#f9e8e8>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9d4d4>f </text><text style=color:#000;background-color:#f9e8e8>o </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9e8e8>d ...
# Cell Number: 400
# <text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>a </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;background-color:#f9d4d4>d </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;padding-left:10px;background-color:#c2e1f0> </text><text style=color:#000;background-color:#f9e8e8>p </text><text style=color:#000;background-color:#f9d4d4>r </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9e8e8>c </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f8a8a8>o </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>f </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f68f8f>e </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f9d4d4>l </text><text style=color:#000;background-color:#f9d4d4>y </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f68f8f>e </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f9e8e8>m </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f9e8e8>t </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#eff7fb>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>
#  </text><text style=color:#000;background-color:#f9d4d4>p </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9e8e8>r </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>f </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f8a8a8>e </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>r </text><text style=color:#000;background-color:#f9e8e8>l </text><text style=color:#000;background-color:#f9e8e8>d </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f47676>i </text><text style=color:#000;background-color:#c2e1f0>c </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;padding-left:10px;background-color:#f9bdbd> </text><text style=color:#000;background-color:#f9d4d4>w </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#eff7fb>s </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>n </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>m </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9e8e8>n </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>w </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f47676>o </text><text style=color:#000;padding-left:10px;background-color:#f9e8e8> </text><text style=color:#000;background-color:#f9e8e8>w </text><text style=color:#000;background-color:#f9d4d4>a </text><text style=color:#000;background-color:#f9e8e8>s </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>s </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>p </text><text style=color:#000;background-color:#f9d4d4>u </text><text style=color:#000;background-color:#f9d4d4>e </text><text style=color:#000;background-color:#f9d4d4>r </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9d4d4>i </text><text style=color:#000;background-color:#f68f8f>o </text><text style=color:#000;background-color:#f9d4d4>g </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9d4d4>t </text><text style=color:#000;background-color:#f9d4d4>h </text><text style=color:#000;background-color:#f68f8f>e </text><text style=color:#000;padding-left:10px;background-color:#f9d4d4> </text><text style=color:#000;background-color:#f9e8e8>f </text><text style=color:#000;background-color:#f9d4d4>o </text><text style=color:#000;background-color:#f9d4d4>r </text><text style=color:#000;background-color:#f9d4d4>d ...
