# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data with three categories: 'Healthy', 'Unhealthy', and 'Average'
data = {
    'Age': [23, 25, 22, 27, 24, 23, 26, 24, 28, 22, 25, 27],
    'ToothLength': [15, 16, 15, 17, 14, 16, 16, 15, 14, 15, 17, 16],
    'Condition': ['Healthy', 'Healthy', 'Unhealthy', 'Healthy', 'Unhealthy', 'Healthy', 
                  'Average', 'Healthy', 'Average', 'Unhealthy', 'Average', 'Average']
}
df = pd.DataFrame(data)


# Define your custom color palette
#custom_palette = ["#4CAF50", "#FFC107", "#F44336"]  # Green, Yellow, Red for example
custom_palette = ["#98FB98", "#FFB6C1","#FFFFCC"]  # Green, Yellow, Red for example

# Boxplot
plt.figure(figsize=(12, 5), dpi=600)
plt.subplot(1, 2, 1)
sns.boxplot(x='Condition', y='ToothLength', data=df, palette=custom_palette)
plt.title('Box Plot of Tooth Length by Condition')

# Violin Plot
plt.subplot(1, 2, 2)
sns.violinplot(x='Condition', y='ToothLength', data=df, palette=custom_palette)
plt.title('Violin Plot of Tooth Length by Condition')

plt.tight_layout()
plt.show()

# %%
! pip install basemap
# Out:
# ...
#   Using cached basemap-1.4.0.zip (166 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
# ...
#   Using cached pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for basemap (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [68 lines of output]
#       <string>:74: RuntimeWarning: Cannot find GEOS library and/or headers in standard locations ('/Users/reza/local', '/Users/reza', '/usr/local', '/usr', '/opt/local', '/opt', '/sw'). Please install the corresponding packages using your software management system or set the environment variable GEOS_DIR to point to the location where GEOS is installed (for example, if 'geos_c.h' is in '/usr/local/include' and 'libgeos_c' is in '/usr/local/lib', then you need to set GEOS_DIR to '/usr/local'
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.basemap import Basemap
from matplotlib.collections import PolyCollection
import numpy as np

map = Basemap(llcrnrlon=-20,llcrnrlat=0,urcrnrlon=15,urcrnrlat=50,)

fig = plt.figure()
ax = Axes3D(fig)

ax.set_axis_off()
ax.azim = 270
ax.dist = 7

polys = []
for polygon in map.landpolygons:
    polys.append(polygon.get_coords())


lc = PolyCollection(polys, edgecolor='black',
                    facecolor='#DDDDDD', closed=False)

ax.add_collection3d(lc)
ax.add_collection3d(map.drawcoastlines(linewidth=0.25))
ax.add_collection3d(map.drawcountries(linewidth=0.35))

lons = np.array([-13.7, -10.8, -13.2, -96.8, -7.99, 7.5, -17.3, -3.7])
lats = np.array([9.6, 6.3, 8.5, 32.7, 12.5, 8.9, 14.7, 40.39])
cases = np.array([1971, 7069, 6073, 4, 6, 20, 1, 1])
deaths = np.array([1192, 2964, 1250, 1, 5, 8, 0, 0])
places = np.array(['Guinea', 'Liberia', 'Sierra Leone','United States', 'Mali', 'Nigeria', 'Senegal', 'Spain'])

x, y = map(lons, lats)

ax.bar3d(x, y, np.zeros(len(x)), 2, 2, deaths, color= 'r', alpha=0.8)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import matplotlib.pyplot as plt
#       2 from mpl_toolkits.mplot3d import Axes3D
# ----> 3 from mpl_toolkits.basemap import Basemap
#       4 from matplotlib.collections import PolyCollection
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'
